# %% [markdown]
# # Initialization

# %%
# Helper functions and common imports
import pandas as pd
from numpy import log10, sqrt
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

def euclid(x, y, df, take_log=False):
    if take_log:
        return sqrt(sum((log10(df[x])-log10(df[y]))**2))
    else:
        return sqrt(sum((df[x]-df[y])**2))
    
def sema(vect, fig):
    #semantics=', '.join('{}={}'.format(x,y) for (x,y) in fig.pepperargs['default'].items() if x != 'conc')
    nv = []
    for line in vect:
        v = []
        for (x,y) in fig.pepperargs[line].items():
            if x == 'conc': continue
            if x == 'max_complex_size': continue
            if x == 'max_complex_count': continue
            if x == 'max_reaction_count': continue
            if x == 'condensed': 
                z = x if y is True else 'detailed'
            else:
                z = '{}={}'.format(x,y)
            #print(z)
            v.append(z)
        nv.append(', '.join(v))
    return nv

# %%
# Retrieve the list of FigureData Objects.
from qian2011 import data; q11 = data()
from qian2011sqrt import data; q11sq = data()

# %% [markdown]
# # Get / Update Peppercorn estimates

# %%
# Generate Peppercorn estimates for every FigureData setup.
verb = 0

Table1 = pd.DataFrame()
for fig in q11:
    print(fig.name)
    fig.pepperargs['ddG'] = fig.pepperargs['default'].copy()
    fig.pepperargs['ddG']['ddG_bind']=0.4
    #fig.pepperargs['seesaw']={'seesaw-rxns':'seesaw-T20-utbr-leak-reduced', 'seesaw-conc':100e-9}
    fig.eval('default', verbose = verb)
    fig.eval('ddG', verbose = verb)
    #fig.eval('seesaw', verbose = verb)
    for df in fig.get_dataframes():
        df['Name']=fig.name# + '-' + df['pepperargs']
        df['Semantics']=sema(df['Semantics'], fig)
        #display(df)
        Table1 = Table1.append(df)
# Out:
# Sup. Fig. 22: Single catalyst, no threshold
# Sup. Fig. 23: Single catalyst and threshold
# Fig. 2C: Two-input OR gate
# Fig. 2C: Two-input AND gate
# Sup. Fig. 26: Three-layer OR cascade
# Sup. Fig. 27: Four-layer OR cascade
# Sup. Fig. 28: Five AND/OR gates, four layers
# Sup. Fig. 29: Four-input OR gates
# Sup. Fig. 29: Four-input AND gates

# %%
display(Table1)
from os import remove
fig = q11[2]
print fig.name
print fig._enumerated
for ef in fig._enumerated:
    print ef
    #remove(ef)
#fig._enumerated = set()
# Out:
#               Input Filename                                       Simulation  \
# 0       tmp/Qian2011-SF22-00                                            I=100
# 1       tmp/Qian2011-SF22-00                                             I=90
# 2       tmp/Qian2011-SF22-00                                             I=80
# 3       tmp/Qian2011-SF22-00                                             I=70
# 4       tmp/Qian2011-SF22-00                                             I=60
# 5       tmp/Qian2011-SF22-00                                             I=50
# 6       tmp/Qian2011-SF22-00                                             I=40
# 7       tmp/Qian2011-SF22-00                                             I=30
# 8       tmp/Qian2011-SF22-00                                             I=20
# 9       tmp/Qian2011-SF22-00                                             I=10
# 0       tmp/Qian2011-SF22-00                                            I=100
# 1       tmp/Qian2011-SF22-00                                             I=90
# 2       tmp/Qian2011-SF22-00                                             I=80
# 3       tmp/Qian2011-SF22-00                                             I=70
# 4       tmp/Qian2011-SF22-00                                             I=60
# 5       tmp/Qian2011-SF22-00                                             I=50
# 6       tmp/Qian2011-SF22-00                                             I=40
# 7       tmp/Qian2011-SF22-00                                             I=30
# 8       tmp/Qian2011-SF22-00                                             I=20
# 9       tmp/Qian2011-SF22-00                                             I=10
# 0       tmp/Qian2011-SF23-00                                            I=100
# 1       tmp/Qian2011-SF23-00                                             I=90
# 2       tmp/Qian2011-SF23-00                                             I=80
# 3       tmp/Qian2011-SF23-00                                             I=70
# 4       tmp/Qian2011-SF23-00                                             I=60
# 5       tmp/Qian2011-SF23-00                                             I=50
# 6       tmp/Qian2011-SF23-00                                             I=40
# 7       tmp/Qian2011-SF23-00                                             I=30
# 8       tmp/Qian2011-SF23-00                                             I=20
# 9       tmp/Qian2011-SF23-00                                             I=10
# ..                       ...                                              ...
# 6       tmp/Qian2011-SF28-00             (((0 or 1) and 1) or 0) or (0 and 0)
# 7       tmp/Qian2011-SF28-00             (((1 or 1) and 0) or 0) or (0 and 1)
# 8       tmp/Qian2011-SF28-00             (((1 or 0) and 0) or 0) or (1 and 0)
# 9       tmp/Qian2011-SF28-00             (((0 or 1) and 0) or 0) or (0 and 1)
# 10      tmp/Qian2011-SF28-00             (((0 or 0) and 1) or 0) or (1 and 0)
# 11      tmp/Qian2011-SF28-00             (((0 or 0) and 0) or 0) or (0 and 0)
# 0    tmp/Qian2011-SF29-OR-00     (1 or 0) or (1 or 0) or (1 or 0) or (1 or 0)
# 1    tmp/Qian2011-SF29-OR-00     (1 or 0) or (1 or 0) or (1 or 0) or (0 or 0)
# 2    tmp/Qian2011-SF29-OR-00     (1 or 0) or (1 or 0) or (0 or 0) or (0 or 0)
# 3    tmp/Qian2011-SF29-OR-00     (0 or 0) or (0 or 0) or (0 or 0) or (1 or 0)
# 4    tmp/Qian2011-SF29-OR-00     (0 or 0) or (0 or 0) or (1 or 0) or (0 or 0)
# 5    tmp/Qian2011-SF29-OR-00     (0 or 0) or (1 or 0) or (0 or 0) or (0 or 0)
# 6    tmp/Qian2011-SF29-OR-00     (1 or 0) or (0 or 0) or (0 or 0) or (0 or 0)
# 7    tmp/Qian2011-SF29-OR-00     (0 or 0) or (0 or 0) or (0 or 0) or (0 or 0)
# 0    tmp/Qian2011-SF29-OR-00     (1 or 0) or (1 or 0) or (1 or 0) or (1 or 0)
# 1    tmp/Qian2011-SF29-OR-00     (1 or 0) or (1 or 0) or (1 or 0) or (0 or 0)
# 2    tmp/Qian2011-SF29-OR-00     (1 or 0) or (1 or 0) or (0 or 0) or (0 or 0)
# 3    tmp/Qian2011-SF29-OR-00     (0 or 0) or (0 or 0) or (0 or 0) or (1 or 0)
# 4    tmp/Qian2011-SF29-OR-00     (0 or 0) or (0 or 0) or (1 or 0) or (0 or 0)
# 5    tmp/Qian2011-SF29-OR-00     (0 or 0) or (1 or 0) or (0 or 0) or (0 or 0)
# 6    tmp/Qian2011-SF29-OR-00     (1 or 0) or (0 or 0) or (0 or 0) or (0 or 0)
# 7    tmp/Qian2011-SF29-OR-00     (0 or 0) or (0 or 0) or (0 or 0) or (0 or 0)
# 0   tmp/Qian2011-SF29-AND-00  (1 or 0) and (1 or 0) and (1 or 0) and (1 or 0)
# 1   tmp/Qian2011-SF29-AND-00  (1 or 0) and (1 or 0) and (1 or 0) and (0 or 0)
# 2   tmp/Qian2011-SF29-AND-00  (1 or 0) and (1 or 0) and (0 or 0) and (0 or 0)
# 3   tmp/Qian2011-SF29-AND-00  (1 or 0) and (1 or 0) and (0 or 0) and (0 or 0)
# 0   tmp/Qian2011-SF29-AND-00  (1 or 0) and (1 or 0) and (1 or 0) and (1 or 0)
# 1   tmp/Qian2011-SF29-AND-00  (1 or 0) and (1 or 0) and (1 or 0) and (0 or 0)
# 2   tmp/Qian2011-SF29-AND-00  (1 or 0) and (1 or 0) and (0 or 0) and (0 or 0)
# 3   tmp/Qian2011-SF29-AND-00  (1 or 0) and (1 or 0) and (0 or 0) and (0 or 0)
#
#    Reporter                            Metric  \
# 0         O   diagonal-crossing-time:2700:100
# 1         O   diagonal-crossing-time:2700:100
# 2         O   diagonal-crossing-time:2700:100
# 3         O   diagonal-crossing-time:2700:100
# 4         O   diagonal-crossing-time:2700:100
# 5         O   diagonal-crossing-time:2700:100
# 6         O   diagonal-crossing-time:2700:100
# 7         O   diagonal-crossing-time:2700:100
# 8         O   diagonal-crossing-time:2700:100
# 9         O   diagonal-crossing-time:2700:100
# 0         O   diagonal-crossing-time:2700:100
# 1         O   diagonal-crossing-time:2700:100
# 2         O   diagonal-crossing-time:2700:100
# 3         O   diagonal-crossing-time:2700:100
# 4         O   diagonal-crossing-time:2700:100
# 5         O   diagonal-crossing-time:2700:100
# 6         O   diagonal-crossing-time:2700:100
# 7         O   diagonal-crossing-time:2700:100
# 8         O   diagonal-crossing-time:2700:100
# 9         O   diagonal-crossing-time:2700:100
# 0         O  diagonal-crossing-time:10800:100
# 1         O  diagonal-crossing-time:10800:100
# 2         O  diagonal-crossing-time:10800:100
# 3         O  diagonal-crossing-time:10800:100
# 4         O  diagonal-crossing-time:10800:100
# 5         O  diagonal-crossing-time:10800:100
# 6         O  diagonal-crossing-time:10800:100
# 7         O  diagonal-crossing-time:10800:100
# 8         O  diagonal-crossing-time:10800:100
# 9         O  diagonal-crossing-time:10800:100
# ..      ...                               ...
# 6         y  diagonal-crossing-time:28800:100
# 7         y  diagonal-crossing-time:28800:100
# 8         y  diagonal-crossing-time:28800:100
# 9         y  diagonal-crossing-time:28800:100
# 10        y  diagonal-crossing-time:28800:100
# 11        y  diagonal-crossing-time:28800:100
# 0         y  diagonal-crossing-time:10800:100
# 1         y  diagonal-crossing-time:10800:100
# 2         y  diagonal-crossing-time:10800:100
# 3         y  diagonal-crossing-time:10800:100
# 4         y  diagonal-crossing-time:10800:100
# 5         y  diagonal-crossing-time:10800:100
# 6         y  diagonal-crossing-time:10800:100
# 7         y  diagonal-crossing-time:10800:100
# 0         y  diagonal-crossing-time:10800:100
# 1         y  diagonal-crossing-time:10800:100
# 2         y  diagonal-crossing-time:10800:100
# 3         y  diagonal-crossing-time:10800:100
# 4         y  diagonal-crossing-time:10800:100
# 5         y  diagonal-crossing-time:10800:100
# 6         y  diagonal-crossing-time:10800:100
# 7         y  diagonal-crossing-time:10800:100
# 0         y  diagonal-crossing-time:36000:100
# 1         y  diagonal-crossing-time:36000:100
# 2         y  diagonal-crossing-time:36000:100
# 3         y  diagonal-crossing-time:36000:100
# 0         y  diagonal-crossing-time:36000:100
# 1         y  diagonal-crossing-time:36000:100
# 2         y  diagonal-crossing-time:36000:100
# 3         y  diagonal-crossing-time:36000:100
#
#                                          Semantics  \
# 0                 condensed, k_fast=1, k_slow=0.01
# 1                 condensed, k_fast=1, k_slow=0.01
# 2                 condensed, k_fast=1, k_slow=0.01
# 3                 condensed, k_fast=1, k_slow=0.01
# 4                 condensed, k_fast=1, k_slow=0.01
# 5                 condensed, k_fast=1, k_slow=0.01
# 6                 condensed, k_fast=1, k_slow=0.01
# 7                 condensed, k_fast=1, k_slow=0.01
# 8                 condensed, k_fast=1, k_slow=0.01
# 9                 condensed, k_fast=1, k_slow=0.01
# 0   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 1   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 2   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 3   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 4   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 5   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 6   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 7   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 8   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 9   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 0                 condensed, k_fast=1, k_slow=0.01
# 1                 condensed, k_fast=1, k_slow=0.01
# 2                 condensed, k_fast=1, k_slow=0.01
# 3                 condensed, k_fast=1, k_slow=0.01
# 4                 condensed, k_fast=1, k_slow=0.01
# 5                 condensed, k_fast=1, k_slow=0.01
# 6                 condensed, k_fast=1, k_slow=0.01
# 7                 condensed, k_fast=1, k_slow=0.01
# 8                 condensed, k_fast=1, k_slow=0.01
# 9                 condensed, k_fast=1, k_slow=0.01
# ..                                             ...
# 6   condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
# 7   condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
# 8   condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
# 9   condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
# 10  condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
# 11  condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
# 0                 condensed, k_fast=1, k_slow=0.01
# 1                 condensed, k_fast=1, k_slow=0.01
# 2                 condensed, k_fast=1, k_slow=0.01
# 3                 condensed, k_fast=1, k_slow=0.01
# 4                 condensed, k_fast=1, k_slow=0.01
# 5                 condensed, k_fast=1, k_slow=0.01
# 6                 condensed, k_fast=1, k_slow=0.01
# 7                 condensed, k_fast=1, k_slow=0.01
# 0   condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
# 1   condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
# 2   condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
# 3   condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
# 4   condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
# 5   condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
# 6   condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
# 7   condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
# 0                 condensed, k_fast=1, k_slow=0.01
# 1                 condensed, k_fast=1, k_slow=0.01
# 2                 condensed, k_fast=1, k_slow=0.01
# 3                 condensed, k_fast=1, k_slow=0.01
# 0   condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
# 1   condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
# 2   condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
# 3   condensed, k_fast=1, ddG_bind=0.4, k_slow=0.01
#
#     Concentration (simulation)  Time (simulation)  Concentration (experiment)  \
# 0                    94.975512         139.038622                       72.89
# 1                    94.611881         146.040567                       71.75
# 2                    94.296629         156.043345                       70.62
# 3                    93.842311         168.046680                       69.18
# 4                    93.294597         184.051125                       67.22
# 5                    92.509692         205.056960                       65.05
# 6                    91.334085         234.065018                       61.75
# 7                    89.660728         280.077799                       57.32
# 8                    86.679959         360.100028                       50.31
# 9                    79.815736         547.151987                       37.53
# 0                    73.747762         710.197277                       72.89
# 1                    72.710614         737.204779                       71.75
# 2                    71.500255         770.213948                       70.62
# 3                    70.012698         810.225063                       69.18
# 4                    68.160503         860.238955                       67.22
# 5                    65.768920         924.256738                       65.05
# 6                    62.584244        1010.280634                       61.75
# 7                    58.072604        1132.314532                       57.32
# 8                    51.081761        1322.367324                       50.31
# 9                    38.184994        1670.464018                       37.53
# 0                    97.133754         310.034448                       83.24
# 1                    96.639503         366.040671                       80.66
# 2                    95.810979         458.050895                       76.28
# 3                    94.103729         640.071119                       67.37
# 4                    88.425218        1252.139127                       39.12
# 5                    32.661612        7272.808090                        9.05
# 6                    19.323824        8714.968330                        6.21
# 7                    12.260148        9477.053006                        4.41
# 8                     7.251186       10017.113010                        2.47
# 9                     3.299401       10445.160570                        1.31
# ..                         ...                ...                         ...
# 6                    66.589385        9630.535030                       42.57
# 7                     0.066423       28781.598980                        2.57
# 8                     0.066424       28781.598980                        2.57
# 9                     0.066424       28781.598980                        2.57
# 10                    0.065636       28781.598980                        2.57
# 11                    0.013379       28797.599870                        2.57
# 0                    97.990680         222.024669                       81.20
# 1                    97.758438         248.027559                       78.40
# 2                    97.257328         300.033337                       74.80
# 3                    95.534988         486.054006                       63.60
# 4                    95.534988         486.054006                       61.20
# 5                    95.534988         486.054006                       59.20
# 6                    95.534988         486.054006                       58.00
# 7                     7.073531       10037.115240                        3.60
# 0                    83.785138        1756.195133                       81.20
# 1                    81.869457        1964.218246                       78.40
# 2                    77.906901        2392.265807                       74.80
# 3                    62.321929        4074.452717                       63.60
# 4                    62.321929        4074.452717                       61.20
# 5                    62.321929        4074.452717                       59.20
# 6                    62.321929        4074.452717                       58.00
# 7                     0.059067       10795.199470                        3.60
# 0                    94.340845        2038.113229                       55.33
# 1                    28.817839       25627.423750                       11.07
# 2                     6.587451       33629.868330                        5.79
# 3                     6.587451       33629.868330                        2.94
# 0                    66.744966       11974.665260                       55.33
# 1                     3.088325       34889.938330                       11.07
# 2                     0.555018       35801.989000                        5.79
# 3                     0.555018       35801.989000                        2.94
#
#     Time (experiment)                                          Name
# 0              738.55   Sup. Fig. 22: Single catalyst, no threshold
# 1              766.03   Sup. Fig. 22: Single catalyst, no threshold
# 2              796.95   Sup. Fig. 22: Single catalyst, no threshold
# 3              834.73   Sup. Fig. 22: Single catalyst, no threshold
# 4              886.26   Sup. Fig. 22: Single catalyst, no threshold
# 5              951.53   Sup. Fig. 22: Single catalyst, no threshold
# 6             1040.84   Sup. Fig. 22: Single catalyst, no threshold
# 7             1157.63   Sup. Fig. 22: Single catalyst, no threshold
# 8             1353.44   Sup. Fig. 22: Single catalyst, no threshold
# 9             1700.38   Sup. Fig. 22: Single catalyst, no threshold
# 0              738.55   Sup. Fig. 22: Single catalyst, no threshold
# 1              766.03   Sup. Fig. 22: Single catalyst, no threshold
# 2              796.95   Sup. Fig. 22: Single catalyst, no threshold
# 3              834.73   Sup. Fig. 22: Single catalyst, no threshold
# 4              886.26   Sup. Fig. 22: Single catalyst, no threshold
# 5              951.53   Sup. Fig. 22: Single catalyst, no threshold
# 6             1040.84   Sup. Fig. 22: Single catalyst, no threshold
# 7             1157.63   Sup. Fig. 22: Single catalyst, no threshold
# 8             1353.44   Sup. Fig. 22: Single catalyst, no threshold
# 9             1700.38   Sup. Fig. 22: Single catalyst, no threshold
# 0             1808.00   Sup. Fig. 23: Single catalyst and threshold
# 1             2081.00   Sup. Fig. 23: Single catalyst and threshold
# 2             2587.00   Sup. Fig. 23: Single catalyst and threshold
# 3             3516.00   Sup. Fig. 23: Single catalyst and threshold
# 4             6590.00   Sup. Fig. 23: Single catalyst and threshold
# 5             9828.00   Sup. Fig. 23: Single catalyst and threshold
# 6            10115.00   Sup. Fig. 23: Single catalyst and threshold
# 7            10265.00   Sup. Fig. 23: Single catalyst and threshold
# 8            10497.00   Sup. Fig. 23: Single catalyst and threshold
# 9            10648.00   Sup. Fig. 23: Single catalyst and threshold
# ..                ...                                           ...
# 6            16420.55  Sup. Fig. 28: Five AND/OR gates, four layers
# 7            28031.62  Sup. Fig. 28: Five AND/OR gates, four layers
# 8            28031.62  Sup. Fig. 28: Five AND/OR gates, four layers
# 9            28031.62  Sup. Fig. 28: Five AND/OR gates, four layers
# 10           28031.62  Sup. Fig. 28: Five AND/OR gates, four layers
# 11           28031.62  Sup. Fig. 28: Five AND/OR gates, four layers
# 0             1925.58             Sup. Fig. 29: Four-input OR gates
# 1             2302.33             Sup. Fig. 29: Four-input OR gates
# 2             2679.07             Sup. Fig. 29: Four-input OR gates
# 3             3809.30             Sup. Fig. 29: Four-input OR gates
# 4             4102.33             Sup. Fig. 29: Four-input OR gates
# 5             4311.63             Sup. Fig. 29: Four-input OR gates
# 6             4479.07             Sup. Fig. 29: Four-input OR gates
# 7            10548.84             Sup. Fig. 29: Four-input OR gates
# 0             1925.58             Sup. Fig. 29: Four-input OR gates
# 1             2302.33             Sup. Fig. 29: Four-input OR gates
# 2             2679.07             Sup. Fig. 29: Four-input OR gates
# 3             3809.30             Sup. Fig. 29: Four-input OR gates
# 4             4102.33             Sup. Fig. 29: Four-input OR gates
# 5             4311.63             Sup. Fig. 29: Four-input OR gates
# 6             4479.07             Sup. Fig. 29: Four-input OR gates
# 7            10548.84             Sup. Fig. 29: Four-input OR gates
# 0            15947.37            Sup. Fig. 29: Four-input AND gates
# 1            31894.74            Sup. Fig. 29: Four-input AND gates
# 2            34263.16            Sup. Fig. 29: Four-input AND gates
# 3            35052.63            Sup. Fig. 29: Four-input AND gates
# 0            15947.37            Sup. Fig. 29: Four-input AND gates
# 1            31894.74            Sup. Fig. 29: Four-input AND gates
# 2            34263.16            Sup. Fig. 29: Four-input AND gates
# 3            35052.63            Sup. Fig. 29: Four-input AND gates
#
# [120 rows x 10 columns]
# Fig. 2C: Two-input OR gate
# set(['tmp/Qian2011-F2C-OR-00-default-enum.pil', 'tmp/Qian2011-F2C-OR-00-ddG-enum.pil'])
# tmp/Qian2011-F2C-OR-00-default-enum.pil
# tmp/Qian2011-F2C-OR-00-ddG-enum.pil

# %% [markdown]
# # Squareroot circuit

# %%
from qian2011sqrt import data; q11sqrt = data()
# modify seesaw reading so that threshold reaction uses kf and not ks, then check simulations with and without utbr to see the difference.
# If utbr still contributes, then we actually lose info due to this one rxn, if not, then it is something we cannot handle anyways.

# ok - reverting the changes. The differences between varinats were very small! so utbr with kfs != krs is not useful.

# %%
# Generate Peppercorn estimates for every FigureData setup.
verb = 1
#Table1 = pd.DataFrame()
for fig in q11sqrt:
    print(fig.name)
    #fig.pepperargs['seesaw']={'seesaw-rxns':'seesaw-T25-utbr-leak-reduced', 'seesaw-conc':50e-9}
    fig.pepperargs['ddG']=fig.pepperargs['default'].copy()
    fig.pepperargs['ddG']['ddG_bind']=0.4
    fig.eval('default', verbose = verb, cmpfig=True)
    #fig.eval('seesaw', verbose = verb, cmpfig=True)
    fig.eval('ddG', verbose=verb, cmpfig=True)
    for df in fig.get_dataframes():
        df['Name']=fig.name
        df['Semantics']=sema(df['Semantics'], fig)
        Table1 = Table1.append(df)
# Out:
# Sup. Fig. 31: Integer 4-bit squareroot circuit
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: default
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG
# tmp/Qian2011-SF31-00: ddG

# %%
#fig=q11sqrt[0]
#fig._enumerated = set(['tmp/Qian2011-SF31-00-CONDENSED-enum.pil'])
#fig._simulated = set(['tmp/Qian2011-SF31-00-CONDENSED-y1_0-1101-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_0-1100-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_0-0110-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_0-0010-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_0-0011-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_1-1010-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_0-0100-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_0-0000-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_1-0011-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_0-0111-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_0-1110-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_1-0100-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_1-0010-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_1-0001-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_0-1000-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_0-1010-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_1-1011-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_1-1101-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_1-0110-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_1-0101-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_0-0101-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_1-1001-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_1-1111-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_0-1011-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_0-1111-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_1-0111-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_1-1000-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_0-1001-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_1-0000-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_1-1100-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_0-0001-simu', 'tmp/Qian2011-SF31-00-CONDENSED-y1_1-1110-simu'])
#fig._simexecs = set(['tmp/Qian2011-SF31-00-CONDENSED-simu.py'])

# %%
# Get Data from File
SQ = q11sqrt[0]
df = pd.read_table(SQ.cmpfig['ddG'], sep='\s+')

time = df.values[:,0]/3600
y1_0 = df.values[:,1:17]
y1_1 = df.values[:,17:33]
y2_0 = df.values[:,33:49]
y2_1 = df.values[:,49:]

#legend = ['20 nM', '6 nM', '2 nM', '1 nM', '0.6 nM', '0.4 nM', '0.2 nM', '0.1 nM', '0.06 nM', '0.02 nM', '0.01 nM', '0 nM']
#legend = list(df)[1:]

#assert ys.shape[1] == len(legend)
plt.figure(figsize=(5.5,4.5))

# Plot the data
plt.plot(time, y1_0, color='blue', linestyle=':')
plt.plot(time, y1_1, color='blue')
plt.plot(time, y2_0, color='red', linestyle=':')
plt.plot(time, y2_1, color='red')
plt.plot([0,8], [40, 0], linewidth=1, color='black', linestyle='--', zorder=1)
plt.xlim(-0.5,10.5)
#plt.xticks(np.arange(0, 21, step=5))

plt.ylim(-3,53)
#plt.yticks(np.arange(0, 21, step=5))

from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], color='blue', linestyle=':', lw=2),
                Line2D([0], [0], color='blue', lw=2),
                Line2D([0], [0], color='red', linestyle=':', lw=2),
                Line2D([0], [0], color='red', lw=2)]
#plt.legend(legend, ncol=1, loc='center right', fontsize=7);
plt.legend(custom_lines, ['$Y_1 0$', '$Y_11$', '$Y_20$', '$Y_21$'])

plt.gca().set_title('Superimposed squareroot circuit simulations.', fontsize=15)
plt.gca().set_xlabel('Time [hours]', fontsize=15)
plt.gca().set_ylabel('Concentration [nM]', fontsize=15)
#plt.gca().axhline(y=10, linewidth=1, color='black', linestyle='--')

plt.savefig('qian2011_sqrt_simu_ddG.pdf', bbox_inches='tight')
plt.savefig('qian2011_sqrt_simu_ddG.svg', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-8-937e64fce0a6> in <module>()
#      17 # Plot the data
#      18 plt.plot(time, y1_0, color='blue', linestyle=':')
# ---> 19 plt.plot(time, y1_1, color='blue')
#      20 plt.plot(time, y2_0, color='red', linestyle=':')
#      21 plt.plot(time, y2_1, color='red')
#
# /home/stefan/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# /home/stefan/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /home/stefan/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1525         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1526
# -> 1527         for line in self._get_lines(*args, **kwargs):
#    1528             self.add_line(line)
#    1529             lines.append(line)
#
# /home/stefan/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# /home/stefan/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _plot_args(self, tup, kwargs)
#     394                                   "with non-matching shapes is deprecated.")
#     395         for j in xrange(max(ncx, ncy)):
# --> 396             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     397             ret.append(seg)
#     398         return ret
#
# ZeroDivisionError: integer division or modulo by zero

# %%
# Get Data from File
SQ = q11sqrt[0]
df = pd.read_table(SQ.cmpfig['seesaw'], sep='\s+')

time = df.values[:,0]/3600
y1_0 = df.values[:,1:17]
y1_1 = df.values[:,17:33]
y2_0 = df.values[:,33:49]
y2_1 = df.values[:,49:]

#legend = ['20 nM', '6 nM', '2 nM', '1 nM', '0.6 nM', '0.4 nM', '0.2 nM', '0.1 nM', '0.06 nM', '0.02 nM', '0.01 nM', '0 nM']
#legend = list(df)[1:]

#assert ys.shape[1] == len(legend)
plt.figure(figsize=(5.5,4.5))

# Plot the data
plt.plot(time, y1_0, color='blue', linestyle=':')
plt.plot(time, y1_1, color='blue')
plt.plot(time, y2_0, color='red', linestyle=':')
plt.plot(time, y2_1, color='red')
plt.plot([0,8], [40, 0], linewidth=1, color='black', linestyle='--', zorder=1)
plt.xlim(-0.5,10.5)
#plt.xticks(np.arange(0, 21, step=5))

plt.ylim(-3,53)
#plt.yticks(np.arange(0, 21, step=5))

from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], color='blue', linestyle=':', lw=2),
                Line2D([0], [0], color='blue', lw=2),
                Line2D([0], [0], color='red', linestyle=':', lw=2),
                Line2D([0], [0], color='red', lw=2)]
#plt.legend(legend, ncol=1, loc='center right', fontsize=7);
plt.legend(custom_lines, ['$Y_1 0$', '$Y_11$', '$Y_20$', '$Y_21$'])

plt.gca().set_title('Superimposed squareroot circuit simulations.', fontsize=15)
plt.gca().set_xlabel('Time [hours]', fontsize=15)
plt.gca().set_ylabel('Concentration [nM]', fontsize=15)
#plt.gca().axhline(y=10, linewidth=1, color='black', linestyle='--')

plt.savefig('qian2011_sqrt_simu_seesaw.pdf', bbox_inches='tight')
plt.savefig('qian2011_sqrt_simu_seesaw.svg', bbox_inches='tight')

# %% [markdown]
# # Seesaw sytems comparison

# %%
display(Table1)
Table1.to_latex('SeesawData.tex', index=False, float_format='{:.3g}'.format)

tmpfig = Table1.copy()
tmpfig['Time (experiment)'] = log10(tmpfig['Time (experiment)'])
tmpfig['Time (simulation)'] = log10(tmpfig['Time (simulation)'])
#tmpfig = tmpfig.loc[tmpfig['pepperargs'].isin(['seesaw'])]
#tmpfig = tmpfig.loc[tmpfig['name'].isin(['Qian2011-SF22', 'Qian2011-SF23'])]
#tmpfig = tmpfig.loc[tmpfig['name'].isin([fig.name for fig in z11])]
#tmpfig.reset_index(inplace=True, drop=True)
#tmpfig = tmpfig.iloc[0:-1]
#tmpfig = tmpfig.iloc[[4,5,6,7,28,29,30,31], :]
#display(tmpfig)

g = sns.relplot(x="Time (experiment)", y="Time (simulation)", hue='Name', col="Semantics", data=tmpfig, col_order=['default', 'ddG'])
 
#plt.xscale('log')
#plt.yscale('log')
(mi, ma)=(2, 5)
plt.xlim(mi, ma)
plt.ylim(mi, ma)

for ax in plt.gcf().get_axes():
    #print(ax)
    ax.plot([mi, ma], [mi, ma], linewidth=1, color='white',zorder=0)
    ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x,y: "$10^{{ {:.1f} }}$".format(x)))
    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x,y: "$10^{{ {:.1f} }}$".format(x)))
    ax.set(xlabel='Experimental diagonal crossing time [seconds]')
    
plt.gcf().get_axes()[0].set(ylabel='Peppercorn diagonal crossing time [seconds]')
#g.set_titles(row_template="{row_name}", col_template="{col_name}")
axes = g.axes.flatten()
axes[0].set_title("Regular toehold binding energy: 1.7 kcal/mol/nucleotide.")
#axes[1].set_title("condensed, $k_{fast} = 1, k_{slow} = 0.01, ddG = 2 kcal/mol$")
axes[1].set_title("Adjusted toehold binding energy: 2.1 kcal/mol/nucleotide.")
#condensed, ddG_bind=0.0, k_fast=1, k_slow=0.01

plt.savefig('seesaw_times_peppercorn.pdf', bbox_inches='tight')
plt.savefig('seesaw_times_peppercorn.svg', bbox_inches='tight')
# Out:
#           Input Filename Simulation Reporter  \
# 0   tmp/Qian2011-SF22-00      I=100        O
# 1   tmp/Qian2011-SF22-00       I=90        O
# 2   tmp/Qian2011-SF22-00       I=80        O
# 3   tmp/Qian2011-SF22-00       I=70        O
# 4   tmp/Qian2011-SF22-00       I=60        O
# 5   tmp/Qian2011-SF22-00       I=50        O
# 6   tmp/Qian2011-SF22-00       I=40        O
# 7   tmp/Qian2011-SF22-00       I=30        O
# 8   tmp/Qian2011-SF22-00       I=20        O
# 9   tmp/Qian2011-SF22-00       I=10        O
# 0   tmp/Qian2011-SF22-00      I=100        O
# 1   tmp/Qian2011-SF22-00       I=90        O
# 2   tmp/Qian2011-SF22-00       I=80        O
# 3   tmp/Qian2011-SF22-00       I=70        O
# 4   tmp/Qian2011-SF22-00       I=60        O
# 5   tmp/Qian2011-SF22-00       I=50        O
# 6   tmp/Qian2011-SF22-00       I=40        O
# 7   tmp/Qian2011-SF22-00       I=30        O
# 8   tmp/Qian2011-SF22-00       I=20        O
# 9   tmp/Qian2011-SF22-00       I=10        O
# 0   tmp/Qian2011-SF23-00      I=100        O
# 1   tmp/Qian2011-SF23-00       I=90        O
# 2   tmp/Qian2011-SF23-00       I=80        O
# 3   tmp/Qian2011-SF23-00       I=70        O
# 4   tmp/Qian2011-SF23-00       I=60        O
# 5   tmp/Qian2011-SF23-00       I=50        O
# 6   tmp/Qian2011-SF23-00       I=40        O
# 7   tmp/Qian2011-SF23-00       I=30        O
# 8   tmp/Qian2011-SF23-00       I=20        O
# 9   tmp/Qian2011-SF23-00       I=10        O
# ..                   ...        ...      ...
# 34  tmp/Qian2011-SF31-00  y2 0-0010     y2_0
# 35  tmp/Qian2011-SF31-00  y2 0-0011     y2_0
# 36  tmp/Qian2011-SF31-00  y2 0-0100     y2_0
# 37  tmp/Qian2011-SF31-00  y2 0-0101     y2_0
# 38  tmp/Qian2011-SF31-00  y2 0-0110     y2_0
# 39  tmp/Qian2011-SF31-00  y2 0-0111     y2_0
# 40  tmp/Qian2011-SF31-00  y2 0-1000     y2_0
# 41  tmp/Qian2011-SF31-00  y2 0-1001     y2_0
# 42  tmp/Qian2011-SF31-00  y2 0-1010     y2_0
# 43  tmp/Qian2011-SF31-00  y2 0-1011     y2_0
# 44  tmp/Qian2011-SF31-00  y2 0-1100     y2_0
# 45  tmp/Qian2011-SF31-00  y2 0-1101     y2_0
# 46  tmp/Qian2011-SF31-00  y2 0-1110     y2_0
# 47  tmp/Qian2011-SF31-00  y2 0-1111     y2_0
# 48  tmp/Qian2011-SF31-00  y2 1-0000     y2_1
# 49  tmp/Qian2011-SF31-00  y2 1-0001     y2_1
# 50  tmp/Qian2011-SF31-00  y2 1-0010     y2_1
# 51  tmp/Qian2011-SF31-00  y2 1-0011     y2_1
# 52  tmp/Qian2011-SF31-00  y2 1-0100     y2_1
# 53  tmp/Qian2011-SF31-00  y2 1-0101     y2_1
# 54  tmp/Qian2011-SF31-00  y2 1-0110     y2_1
# 55  tmp/Qian2011-SF31-00  y2 1-0111     y2_1
# 56  tmp/Qian2011-SF31-00  y2 1-1000     y2_1
# 57  tmp/Qian2011-SF31-00  y2 1-1001     y2_1
# 58  tmp/Qian2011-SF31-00  y2 1-1010     y2_1
# 59  tmp/Qian2011-SF31-00  y2 1-1011     y2_1
# 60  tmp/Qian2011-SF31-00  y2 1-1100     y2_1
# 61  tmp/Qian2011-SF31-00  y2 1-1101     y2_1
# 62  tmp/Qian2011-SF31-00  y2 1-1110     y2_1
# 63  tmp/Qian2011-SF31-00  y2 1-1111     y2_1
#
#                               Metric  \
# 0    diagonal-crossing-time:2700:100
# 1    diagonal-crossing-time:2700:100
# 2    diagonal-crossing-time:2700:100
# 3    diagonal-crossing-time:2700:100
# 4    diagonal-crossing-time:2700:100
# 5    diagonal-crossing-time:2700:100
# 6    diagonal-crossing-time:2700:100
# 7    diagonal-crossing-time:2700:100
# 8    diagonal-crossing-time:2700:100
# 9    diagonal-crossing-time:2700:100
# 0    diagonal-crossing-time:2700:100
# 1    diagonal-crossing-time:2700:100
# 2    diagonal-crossing-time:2700:100
# 3    diagonal-crossing-time:2700:100
# 4    diagonal-crossing-time:2700:100
# 5    diagonal-crossing-time:2700:100
# 6    diagonal-crossing-time:2700:100
# 7    diagonal-crossing-time:2700:100
# 8    diagonal-crossing-time:2700:100
# 9    diagonal-crossing-time:2700:100
# 0   diagonal-crossing-time:10800:100
# 1   diagonal-crossing-time:10800:100
# 2   diagonal-crossing-time:10800:100
# 3   diagonal-crossing-time:10800:100
# 4   diagonal-crossing-time:10800:100
# 5   diagonal-crossing-time:10800:100
# 6   diagonal-crossing-time:10800:100
# 7   diagonal-crossing-time:10800:100
# 8   diagonal-crossing-time:10800:100
# 9   diagonal-crossing-time:10800:100
# ..                               ...
# 34   diagonal-crossing-time:36000:50
# 35   diagonal-crossing-time:36000:50
# 36   diagonal-crossing-time:36000:50
# 37   diagonal-crossing-time:36000:50
# 38   diagonal-crossing-time:36000:50
# 39   diagonal-crossing-time:36000:50
# 40   diagonal-crossing-time:36000:50
# 41   diagonal-crossing-time:36000:50
# 42   diagonal-crossing-time:36000:50
# 43   diagonal-crossing-time:36000:50
# 44   diagonal-crossing-time:36000:50
# 45   diagonal-crossing-time:36000:50
# 46   diagonal-crossing-time:36000:50
# 47   diagonal-crossing-time:36000:50
# 48   diagonal-crossing-time:36000:50
# 49   diagonal-crossing-time:36000:50
# 50   diagonal-crossing-time:36000:50
# 51   diagonal-crossing-time:36000:50
# 52   diagonal-crossing-time:36000:50
# 53   diagonal-crossing-time:36000:50
# 54   diagonal-crossing-time:36000:50
# 55   diagonal-crossing-time:36000:50
# 56   diagonal-crossing-time:36000:50
# 57   diagonal-crossing-time:36000:50
# 58   diagonal-crossing-time:36000:50
# 59   diagonal-crossing-time:36000:50
# 60   diagonal-crossing-time:36000:50
# 61   diagonal-crossing-time:36000:50
# 62   diagonal-crossing-time:36000:50
# 63   diagonal-crossing-time:36000:50
#
#                                          Semantics  \
# 0                 condensed, k_fast=1, k_slow=0.01
# 1                 condensed, k_fast=1, k_slow=0.01
# 2                 condensed, k_fast=1, k_slow=0.01
# 3                 condensed, k_fast=1, k_slow=0.01
# 4                 condensed, k_fast=1, k_slow=0.01
# 5                 condensed, k_fast=1, k_slow=0.01
# 6                 condensed, k_fast=1, k_slow=0.01
# 7                 condensed, k_fast=1, k_slow=0.01
# 8                 condensed, k_fast=1, k_slow=0.01
# 9                 condensed, k_fast=1, k_slow=0.01
# 0   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 1   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 2   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 3   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 4   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 5   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 6   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 7   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 8   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 9   condensed, ddG_bind=0.4, k_fast=1, k_slow=0.01
# 0                 condensed, k_fast=1, k_slow=0.01
# 1                 condensed, k_fast=1, k_slow=0.01
# 2                 condensed, k_fast=1, k_slow=0.01
# 3                 condensed, k_fast=1, k_slow=0.01
# 4                 condensed, k_fast=1, k_slow=0.01
# 5                 condensed, k_fast=1, k_slow=0.01
# 6                 condensed, k_fast=1, k_slow=0.01
# 7                 condensed, k_fast=1, k_slow=0.01
# 8                 condensed, k_fast=1, k_slow=0.01
# 9                 condensed, k_fast=1, k_slow=0.01
# ..                                             ...
# 34      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 35      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 36      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 37      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 38      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 39      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 40      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 41      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 42      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 43      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 44      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 45      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 46      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 47      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 48      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 49      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 50      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 51      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 52      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 53      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 54      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 55      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 56      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 57      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 58      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 59      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 60      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 61      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 62      seesaw-conc=5e-08, condensed, ddG_bind=0.4
# 63      seesaw-conc=5e-08, condensed, ddG_bind=0.4
#
#     Concentration (simulation)  Time (simulation)  Concentration (experiment)  \
# 0                    94.975512         139.038622                       72.89
# 1                    94.611881         146.040567                       71.75
# 2                    94.296629         156.043345                       70.62
# 3                    93.842311         168.046680                       69.18
# 4                    93.294597         184.051125                       67.22
# 5                    92.509692         205.056960                       65.05
# 6                    91.334085         234.065018                       61.75
# 7                    89.660728         280.077799                       57.32
# 8                    86.679959         360.100028                       50.31
# 9                    79.815736         547.151987                       37.53
# 0                    73.747762         710.197277                       72.89
# 1                    72.710614         737.204779                       71.75
# 2                    71.500255         770.213948                       70.62
# 3                    70.012698         810.225063                       69.18
# 4                    68.160503         860.238955                       67.22
# 5                    65.768920         924.256738                       65.05
# 6                    62.584244        1010.280634                       61.75
# 7                    58.072604        1132.314532                       57.32
# 8                    51.081761        1322.367324                       50.31
# 9                    38.184994        1670.464018                       37.53
# 0                    97.133754         310.034448                       83.24
# 1                    96.639503         366.040671                       80.66
# 2                    95.810979         458.050895                       76.28
# 3                    94.103729         640.071119                       67.37
# 4                    88.425218        1252.139127                       39.12
# 5                    32.661612        7272.808090                        9.05
# 6                    19.323824        8714.968330                        6.21
# 7                    12.260148        9477.053006                        4.41
# 8                     7.251186       10017.113010                        2.47
# 9                     3.299401       10445.160570                        1.31
# ..                         ...                ...                         ...
# 34                   38.236438        8472.470693                       30.00
# 35                   38.245459        8466.470359                       30.00
# 36                    1.166552       35161.953440                        5.00
# 37                    1.166549       35161.953440                        5.00
# 38                    1.166549       35161.953440                        5.00
# 39                    1.166548       35161.953440                        5.00
# 40                    1.166548       35161.953440                        5.50
# 41                    1.166546       35161.953440                        5.50
# 42                    1.166546       35161.953440                        5.50
# 43                    1.166544       35161.953440                        5.50
# 44                    0.012222       35991.999560                        4.00
# 45                    0.012222       35991.999560                        4.00
# 46                    0.012222       35991.999560                        4.00
# 47                    0.012222       35991.999560                        4.00
# 48                    0.024626       35983.999110                        5.00
# 49                    0.024626       35983.999110                        5.00
# 50                    0.024626       35983.999110                        5.00
# 51                    0.024626       35983.999110                        5.00
# 52                   38.969086        7944.441358                       37.50
# 53                   38.966140        7944.441358                       37.50
# 54                   38.966140        7944.441358                       37.50
# 55                   38.971426        7946.441469                       37.50
# 56                   38.999279        7924.440247                       40.00
# 57                   38.997389        7924.440247                       40.00
# 58                   38.997389        7924.440247                       40.00
# 59                   38.997725        7924.440247                       40.00
# 60                   43.505950        4676.259792                       40.00
# 61                   43.509921        4678.259903                       40.00
# 62                   43.509921        4678.259903                       40.00
# 63                   43.509676        4678.259903                       40.00
#
#     Time (experiment)                                            Name
# 0              738.55     Sup. Fig. 22: Single catalyst, no threshold
# 1              766.03     Sup. Fig. 22: Single catalyst, no threshold
# 2              796.95     Sup. Fig. 22: Single catalyst, no threshold
# 3              834.73     Sup. Fig. 22: Single catalyst, no threshold
# 4              886.26     Sup. Fig. 22: Single catalyst, no threshold
# 5              951.53     Sup. Fig. 22: Single catalyst, no threshold
# 6             1040.84     Sup. Fig. 22: Single catalyst, no threshold
# 7             1157.63     Sup. Fig. 22: Single catalyst, no threshold
# 8             1353.44     Sup. Fig. 22: Single catalyst, no threshold
# 9             1700.38     Sup. Fig. 22: Single catalyst, no threshold
# 0              738.55     Sup. Fig. 22: Single catalyst, no threshold
# 1              766.03     Sup. Fig. 22: Single catalyst, no threshold
# 2              796.95     Sup. Fig. 22: Single catalyst, no threshold
# 3              834.73     Sup. Fig. 22: Single catalyst, no threshold
# 4              886.26     Sup. Fig. 22: Single catalyst, no threshold
# 5              951.53     Sup. Fig. 22: Single catalyst, no threshold
# 6             1040.84     Sup. Fig. 22: Single catalyst, no threshold
# 7             1157.63     Sup. Fig. 22: Single catalyst, no threshold
# 8             1353.44     Sup. Fig. 22: Single catalyst, no threshold
# 9             1700.38     Sup. Fig. 22: Single catalyst, no threshold
# 0             1808.00     Sup. Fig. 23: Single catalyst and threshold
# 1             2081.00     Sup. Fig. 23: Single catalyst and threshold
# 2             2587.00     Sup. Fig. 23: Single catalyst and threshold
# 3             3516.00     Sup. Fig. 23: Single catalyst and threshold
# 4             6590.00     Sup. Fig. 23: Single catalyst and threshold
# 5             9828.00     Sup. Fig. 23: Single catalyst and threshold
# 6            10115.00     Sup. Fig. 23: Single catalyst and threshold
# 7            10265.00     Sup. Fig. 23: Single catalyst and threshold
# 8            10497.00     Sup. Fig. 23: Single catalyst and threshold
# 9            10648.00     Sup. Fig. 23: Single catalyst and threshold
# ..                ...                                             ...
# 34           10800.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 35           10800.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 36           24480.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 37           24480.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 38           24480.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 39           24480.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 40           25200.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 41           25200.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 42           25200.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 43           25200.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 44           25920.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 45           25920.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 46           25920.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 47           25920.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 48           25200.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 49           25200.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 50           25200.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 51           25200.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 52            7200.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 53            7200.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 54            7200.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 55            7200.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 56            6480.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 57            6480.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 58            6480.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 59            6480.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 60            7200.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 61            7200.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 62            7200.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
# 63            7200.00  Sup. Fig. 31: Integer 4-bit squareroot circuit
#
# [248 rows x 10 columns]

# %%
tmpfig = Table1.copy()
tmpfig['Time (experiment)'] = log10(tmpfig['Time (experiment)'])
tmpfig['Time (simulation)'] = log10(tmpfig['Time (simulation)'])

g = sns.relplot(x="Time (experiment)", y="Time (simulation)", hue='Name', col="Semantics", data=tmpfig, col_order=['seesaw'])
 
#plt.xscale('log')
#plt.yscale('log')
(mi, ma)=(2, 5)
#plt.xlim(mi, ma)
#plt.ylim(mi, ma)

for ax in plt.gcf().get_axes():
    #print(ax)
    ax.plot([mi, ma], [mi, ma], linewidth=1, color='white',zorder=0)
    ax.set(xlabel='Experimental diagonal crossing time [seconds]')
    ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x,y: "$10^{{ {:.1f} }}$".format(x)))
    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x,y: "$10^{{ {:.1f} }}$".format(x)))
    
plt.gcf().get_axes()[0].set(ylabel='Seesaw model diagonal crossing time [seconds]')
g.set_titles(row_template="{row_name}", col_template="{col_name}")
axes = g.axes.flatten()
axes[0].set_title("Seesaw reaction model Qian & Winfree (2011)")
#axes[1].set_title("Toehold binding energy $T = T+2.0$ kcal/mol")
#condensed, ddG_bind=0.0, k_fast=1, k_slow=0.01

plt.savefig('seesaw_times_qian.pdf', bbox_inches='tight')
plt.savefig('seesaw_times_qian.svg', bbox_inches='tight')
