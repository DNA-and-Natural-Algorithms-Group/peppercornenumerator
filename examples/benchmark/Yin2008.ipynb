# %%
import numpy as np
from pandas import DataFrame
from yin2008 import data; y08 = data()

# %%
verb=0
for fig in y08:
    print fig.name
    fig.pepperargs['ddG_2']=fig.pepperargs['default'].copy()
    fig.pepperargs['ddG_2']['ddG_bind'] = 2
    fig.pepperargs['reject-remote']=fig.pepperargs['condensed'].copy()
    fig.pepperargs['reject-remote']['remote_migration'] = False
    fig.eval('default', verbose=verb, cmpfig=True)
    fig.eval('reject-remote', verbose=verb, cmpfig=True)
    fig.eval('ddG_2', verbose=verb, cmpfig=True)
# Out:
# Yin2008-F3

# %%
Table1 = DataFrame()
for fig in y08:
    for df in fig.get_dataframes():
        df['name'] = fig.name
        display(df)
        Table1 = Table1.append(df)
# Out:
#               pilfile simulation reporter           metric  exp-conc  \
# 0   tmp/Yin2008-F3-00       I=20        A  completion-time       -10
# 1   tmp/Yin2008-F3-00        I=6        A  completion-time       -10
# 2   tmp/Yin2008-F3-00        I=2        A  completion-time       -10
# 3   tmp/Yin2008-F3-00        I=1        A  completion-time       -10
# 4   tmp/Yin2008-F3-00      I=0.6        A  completion-time       -10
# 5   tmp/Yin2008-F3-00      I=0.4        A  completion-time       -10
# 6   tmp/Yin2008-F3-00      I=0.2        A  completion-time       -10
# 7   tmp/Yin2008-F3-00      I=0.1        A  completion-time       -10
# 8   tmp/Yin2008-F3-00     I=0.06        A  completion-time       -10
# 9   tmp/Yin2008-F3-00     I=0.02        A  completion-time       -10
# 10  tmp/Yin2008-F3-00     I=0.01        A  completion-time       -10
# 11  tmp/Yin2008-F3-00        I=0        A  completion-time       -10
#
#     exp-time pepperargs  sim-conc    sim-time        name
# 0         43    default       -10   28.001556  Yin2008-F3
# 1       1064    default       -10   96.005334  Yin2008-F3
# 2       3505    default       -10  183.010167  Yin2008-F3
# 3       5341    default       -10  236.013112  Yin2008-F3
# 4       6893    default       -10  275.015279  Yin2008-F3
# 5       7706    default       -10  305.016945  Yin2008-F3
# 6       8842    default       -10  356.019779  Yin2008-F3
# 7       9731    default       -10  406.022557  Yin2008-F3
# 8      10242    default       -10  443.024612  Yin2008-F3
# 9      10696    default       -10  521.028946  Yin2008-F3
# 10     10885    default       -10  571.031724  Yin2008-F3
# 11     11112    default       -10         NaN  Yin2008-F3
#               pilfile simulation reporter           metric  exp-conc  \
# 0   tmp/Yin2008-F3-00       I=20        A  completion-time       -10
# 1   tmp/Yin2008-F3-00        I=6        A  completion-time       -10
# 2   tmp/Yin2008-F3-00        I=2        A  completion-time       -10
# 3   tmp/Yin2008-F3-00        I=1        A  completion-time       -10
# 4   tmp/Yin2008-F3-00      I=0.6        A  completion-time       -10
# 5   tmp/Yin2008-F3-00      I=0.4        A  completion-time       -10
# 6   tmp/Yin2008-F3-00      I=0.2        A  completion-time       -10
# 7   tmp/Yin2008-F3-00      I=0.1        A  completion-time       -10
# 8   tmp/Yin2008-F3-00     I=0.06        A  completion-time       -10
# 9   tmp/Yin2008-F3-00     I=0.02        A  completion-time       -10
# 10  tmp/Yin2008-F3-00     I=0.01        A  completion-time       -10
# 11  tmp/Yin2008-F3-00        I=0        A  completion-time       -10
#
#     exp-time pepperargs  sim-conc     sim-time        name
# 0         43      ddG_2       -10    99.005500  Yin2008-F3
# 1       1064      ddG_2       -10   281.015612  Yin2008-F3
# 2       3505      ddG_2       -10   497.027613  Yin2008-F3
# 3       5341      ddG_2       -10   632.035113  Yin2008-F3
# 4       6893      ddG_2       -10   730.040558  Yin2008-F3
# 5       7706      ddG_2       -10   806.044780  Yin2008-F3
# 6       8842      ddG_2       -10   933.051836  Yin2008-F3
# 7       9731      ddG_2       -10  1059.058837  Yin2008-F3
# 8      10242      ddG_2       -10  1152.064004  Yin2008-F3
# 9      10696      ddG_2       -10  1349.074949  Yin2008-F3
# 10     10885      ddG_2       -10  1473.081838  Yin2008-F3
# 11     11112      ddG_2       -10          NaN  Yin2008-F3
#               pilfile simulation reporter           metric  exp-conc  \
# 0   tmp/Yin2008-F3-00       I=20        A  completion-time       -10
# 1   tmp/Yin2008-F3-00        I=6        A  completion-time       -10
# 2   tmp/Yin2008-F3-00        I=2        A  completion-time       -10
# 3   tmp/Yin2008-F3-00        I=1        A  completion-time       -10
# 4   tmp/Yin2008-F3-00      I=0.6        A  completion-time       -10
# 5   tmp/Yin2008-F3-00      I=0.4        A  completion-time       -10
# 6   tmp/Yin2008-F3-00      I=0.2        A  completion-time       -10
# 7   tmp/Yin2008-F3-00      I=0.1        A  completion-time       -10
# 8   tmp/Yin2008-F3-00     I=0.06        A  completion-time       -10
# 9   tmp/Yin2008-F3-00     I=0.02        A  completion-time       -10
# 10  tmp/Yin2008-F3-00     I=0.01        A  completion-time       -10
# 11  tmp/Yin2008-F3-00        I=0        A  completion-time       -10
#
#     exp-time     pepperargs  sim-conc    sim-time        name
# 0         43  reject-remote       -10   28.001556  Yin2008-F3
# 1       1064  reject-remote       -10   96.005334  Yin2008-F3
# 2       3505  reject-remote       -10  182.010112  Yin2008-F3
# 3       5341  reject-remote       -10  235.013056  Yin2008-F3
# 4       6893  reject-remote       -10  273.015167  Yin2008-F3
# 5       7706  reject-remote       -10  303.016834  Yin2008-F3
# 6       8842  reject-remote       -10  354.019668  Yin2008-F3
# 7       9731  reject-remote       -10  404.022446  Yin2008-F3
# 8      10242  reject-remote       -10  440.024446  Yin2008-F3
# 9      10696  reject-remote       -10  519.028835  Yin2008-F3
# 10     10885  reject-remote       -10  568.031557  Yin2008-F3
# 11     11112  reject-remote       -10         NaN  Yin2008-F3

# %%
import matplotlib.pyplot as plt
from numpy import log10
import seaborn as sns
sns.set(style="darkgrid")

tmpfig = Table1.copy()
tmpfig['exp-time'] = log10(tmpfig['exp-time'])
tmpfig['sim-time'] = log10(tmpfig['sim-time'])
tmpfig = tmpfig.loc[tmpfig['pepperargs'].isin(['default'])]
#tmpfig = tmpfig.loc[tmpfig['name'].isin(['Qian2011-SF22', 'Qian2011-SF23'])]
#display(tmpfig)

sns.lmplot(x="exp-time", y="sim-time", data=tmpfig)

#plt.xscale('log')
#plt.yscale('log')
(mi, ma)=(1, 4)
#plt.xlim(mi, ma)
#plt.ylim(mi, ma)
plt.plot([mi, ma], [mi, ma], linewidth=1, color='white',zorder=0)
plt.gcf().set_size_inches(3.5,2.5)

#plt.savefig('yinF3_hct.pdf', bbox_inches='tight')
#plt.savefig('yinF3_hct.svg', bbox_inches='tight')
# Out:
# /home/stefan/anaconda3/envs/py27/lib/python2.7/site-packages/scipy-1.1.0-py2.7-linux-x86_64.egg/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Get Data from File
F3 = y08[0]
nxy = np.loadtxt(F3.cmpfig['default'], skiprows=1)

print F3.cmpfig['default']

time = nxy[:,0] / 60
ys = nxy[:,1:]
legend = ['20 nM', '6 nM', '2 nM', '1 nM', '0.6 nM', '0.4 nM', '0.2 nM', '0.1 nM', '0.06 nM', '0.02 nM', '0.01 nM', '0 nM']
legend = map(lambda x: '{}{}'.format('I = ', x), legend)

assert ys.shape[1] == len(legend)

# Customize plot using Yin 2008 color scheme, etc.
mycolors = ['#882486', 
            '#ffbb11', 
            '#ea0081', 
            '#eb1c22',
            '#f68a1d',
            '#0faa44', 
            '#87398e', 
            '#2b2d89',
            '#016667',
            '#027ac5',
            '#eb125b',
            '#211e1f']

plt.figure(figsize=(3.5,2.5))
plt.gca().set_prop_cycle(color=mycolors)
#sns.set(rc={'figure.figsize':(3.5,2.5)})

#plt.gca().invert_yaxis()

# Plot the data
plt.plot(time, ys)

plt.xlim(-0.5,20.5)
plt.xticks(np.arange(0, 21, step=5))

plt.ylim(21,-1)
plt.yticks(np.arange(0, 21, step=5))

plt.legend(legend, ncol=1, loc='center right', fontsize=7);
plt.gca().set_xlabel('Time [min]', fontsize=10)
plt.gca().set_ylabel('Concentration A [nM]', fontsize=10)
plt.gca().axhline(y=10, linewidth=1, color='black', linestyle='--')

#plt.savefig('yinF3.pdf', bbox_inches='tight')
#plt.savefig('yinF3.svg', bbox_inches='tight')
# Out:
# tmp/Yin2008-F3-00-default-cmp.nxy

# %%
import pandas as pd
F3 = y08[0]
df = pd.read_table(F3.cmpfig['default'], sep='\s+') 
print df.head().to_csv(sep='\t', float_format='%.9e', index = False, 
                                                header = ['{:15s}'.format(x) for x in list(df)])
# Out:
# time           	I=20           	I=6            	I=2            	I=1            	I=0.6          	I=0.4          	I=0.2          	I=0.1          	I=0.06         	I=0.02         	I=0.01         	I=0
# 0.000000000e+00	2.000000000e+01	2.000000000e+01	2.000000000e+01	2.000000000e+01	2.000000000e+01	2.000000000e+01	2.000000000e+01	2.000000000e+01	2.000000000e+01	2.000000000e+01	2.000000000e+01	2.000000000e+01
# 1.000055559e+00	1.936987684e+01	1.980886284e+01	1.993608573e+01	1.996801756e+01	1.998080446e+01	1.998720095e+01	1.999359946e+01	1.999679948e+01	1.999807963e+01	1.999935985e+01	1.999967992e+01	2.000000000e+01
# 2.000111117e+00	1.877783232e+01	1.962539290e+01	1.987435961e+01	1.993708291e+01	1.996222646e+01	1.997480987e+01	1.998740105e+01	1.999369955e+01	1.999621950e+01	1.999873976e+01	1.999936987e+01	2.000000000e+01
# 3.000166676e+00	1.821989923e+01	1.944897638e+01	1.981466537e+01	1.990712370e+01	1.994422396e+01	1.996279921e+01	1.998139122e+01	1.999069351e+01	1.999441560e+01	1.999813837e+01	1.999906916e+01	2.000000000e+01
# 4.000222235e+00	1.769263823e+01	1.927905604e+01	1.975685853e+01	1.987807271e+01	1.992675784e+01	1.995114327e+01	1.997555731e+01	1.998777507e+01	1.999266418e+01	1.999755444e+01	1.999877718e+01	2.000000000e+01
